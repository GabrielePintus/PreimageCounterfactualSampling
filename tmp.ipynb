# %%
from src.training.datamodules.adult import AdultDataModule

# %%
dm = AdultDataModule(batch_size=64)
dm.prepare_data()
dm.setup()

# %%
train_loader = dm.train_dataloader()
batch = next(iter(train_loader))

# %%
batch[0][0].numpy()
# Out:
# array([ 1.5530787e+00,  1.0000000e+00,  3.6348099e-01,  0.0000000e+00,
#        -1.5876467e+00,  0.0000000e+00,  0.0000000e+00,  4.0000000e+00,
#         4.0000000e+00,  0.0000000e+00, -1.4406092e-01, -2.1714072e-01,
#        -3.6761779e-02,  3.8000000e+01], dtype=float32)
