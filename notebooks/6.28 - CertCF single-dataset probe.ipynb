# %% [markdown]
# # CertCF Single-Dataset Probe
#
# Run CertCF on one non-Adult dataset, then inspect validity, distance, solver metadata, failures, and the feature-level changes for individual counterfactuals.

# %%
from pathlib import Path
import subprocess, sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from counterfactuals.datasets.loaders import (
    AdultDataset, CompasDataset, GermanCreditDataset, GiveMeSomeCreditDataset,
    HELOCDataset, LendingClubDataset, WisconsinBreastCancerDataset,
)

CONFIG = ROOT / "configs/benchmarks/certcf_single_dataset_probe.yaml"

DATASET_LOADERS = {
    "adult": AdultDataset,
    "compas": CompasDataset,
    "german_credit": GermanCreditDataset,
    "give_me_some_credit": GiveMeSomeCreditDataset,
    "heloc": HELOCDataset,
    "lending_club": LendingClubDataset,
    "wisconsin_breast_cancer": WisconsinBreastCancerDataset,
}

# %% [markdown]
# Choose one dataset. The default is `give_me_some_credit`, which has 10 encoded dimensions. Other supported choices here are `compas`, `heloc`, `lending_club`, `german_credit`, and `wisconsin_breast_cancer`.

# %%
DATASET = "adult"
N_QUERIES = 1000
RUN_BENCHMARK = True
METHOD_TO_INSPECT = "certcf_probe"

result_path = ROOT / f"results/certcf_probe_{DATASET}.parquet"
if RUN_BENCHMARK:
    cmd = [
        sys.executable, str(ROOT / "scripts/benchmark.py"),
        "--config", str(CONFIG),
        # "--datasets", DATASET,
        "--n_queries", str(N_QUERIES),
        "--output", str(result_path),
    ]
    subprocess.run(cmd, cwd=ROOT, check=True)

df = pd.read_parquet(result_path)
df.shape
# Out:
# ============================================================
# [DATASET 1/7]  give_me_some_credit
# ============================================================
# [INFO] Loading TabularClassifier from checkpoint: checkpoints/give_me_some_credit_classifier/best.ckpt
# [INFO] model device normalized: 'auto' -> 'cuda'
# [INFO] Train accuracy: 0.827
# [INFO] 1000 benchmark tasks selected from 15000 test samples.
# [INFO] Preprocessing: identity (10 -> 10 dims).
# [INFO] 2 method runs after grid expansion.
#
# [METHOD] nn_probe (impl: nearest_neighbor)
#   [build] 0.00s
#   nn_probe: 100%|█| 1000/1000 [00:00<00:00, 1798.32query/s, failed=0, valid=100
# Computing bounds:   0%|                                  | 0/2 [00:00<?, ?it/s]/home/gabrielepintus/.conda/envs/py13/lib/python3.13/site-packages/auto_LiRPA/perturbations.py:199: RuntimeWarning: divide by zero encountered in scalar divide
#   self.dual_norm = 1 if (norm == np.inf) else (np.float64(1.0) / (1 - 1.0 / self.norm))
# [METHOD] certcf_backward (impl: certcf)
# [INFO] certcf device normalized: 'auto' -> 'cuda'
# Building certified atlas (eps in [0.03622, 10.6] (NearestOppositeClassClearanceStrategy), L1 norm)...
#   Computing LiRPA bounds...
# /home/gabrielepintus/.conda/envs/py13/lib/python3.13/site-packages/auto_LiRPA/operators/linear.py:650: RuntimeWarning: divide by zero encountered in scalar divide
#   dual_norm = np.float64(1.0) / (1 - 1.0 / norm)
#
#   nn_probe: 100%|█| 1000/1000 [00:20<00:00, 1798.32query/s, failed=0, valid=100
# Computing bounds: 100%|██████████████████████████| 2/2 [00:32<00:00, 16.34s/it]
#
#   nn_probe: 100%|█| 1000/1000 [00:33<00:00, 30.05query/s, failed=0, valid=1000]
#
#   certcf_backward:   0%| | 1/1000 [00:00<00:14, 69.54query/s, failed=0, valid=1
#   certcf_backward:   0%| | 2/1000 [00:00<00:11, 88.35query/s, failed=0, valid=2
#   certcf_backward:   0%| | 3/1000 [00:00<00:10, 97.05query/s, failed=0, valid=3
#   certcf_backward:   0%| | 4/1000 [00:00<00:09, 109.11query/s, failed=0, valid=
#   certcf_backward:   0%| | 5/1000 [00:00<00:08, 117.93query/s, failed=0, valid=
#   certcf_backward:   1%| | 6/1000 [00:00<00:08, 122.87query/s, failed=0, valid=
#   certcf_backward:   1%| | 7/1000 [00:00<00:08, 111.85query/s, failed=0, valid=
#   certcf_backward:   1%| | 8/1000 [00:00<00:08, 115.93query/s, failed=0, valid=
#   certcf_backward:   1%| | 9/1000 [00:00<00:08, 115.39query/s, failed=0, valid=
#   certcf_backward:   1%| | 10/1000 [00:00<00:08, 112.92query/s, failed=0, valid
#   certcf_backward:   1%| | 11/1000 [00:00<00:08, 116.09query/s, failed=0, valid
#   certcf_backward:   1%| | 12/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   1%| | 12/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   1%| | 13/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   1%| | 14/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 15/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 16/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 17/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 18/1000 [00:00<00:09, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 19/1000 [00:00<00:08, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 20/1000 [00:00<00:08, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 21/1000 [00:00<00:08, 109.05query/s, failed=0, valid
#   Building BVH spatial indices...
#     Class 0: 1000 polytopes, tree depth 11
#     Class 1: 1000 polytopes, tree depth 11
# Done! Total: 2000 polytopes across 2 classes
#   [build] 32.71s
#   certcf_backward:   2%| | 22/1000 [00:00<00:08, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 23/1000 [00:00<00:08, 109.05query/s, failed=0, valid
#   certcf_backward:   2%| | 24/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   2%| | 24/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   2%| | 25/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 26/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 27/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 28/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 29/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 30/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 31/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 32/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 33/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   3%| | 34/1000 [00:00<00:09, 106.87query/s, failed=0, valid
#   certcf_backward:   4%| | 35/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 35/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 36/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 37/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 38/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 39/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 40/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 41/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 42/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 43/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 44/1000 [00:00<00:09, 98.86query/s, failed=0, valid=
#   certcf_backward:   4%| | 45/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   4%| | 45/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 46/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 47/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 48/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 49/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 50/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 51/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 52/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 53/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   5%| | 54/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   6%| | 55/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   6%| | 56/1000 [00:00<00:10, 90.46query/s, failed=0, valid=
#   certcf_backward:   6%| | 57/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 57/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 58/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 59/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 60/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 61/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 62/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 63/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 64/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   6%| | 65/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   7%| | 66/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   7%| | 67/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   7%| | 68/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   7%| | 69/1000 [00:00<00:09, 94.77query/s, failed=0, valid=
#   certcf_backward:   7%| | 70/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   7%| | 70/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   7%| | 71/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   7%| | 72/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   7%| | 73/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   7%| | 74/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| | 75/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| | 76/1000 [00:00<00:09, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| | 77/1000 [00:00<00:08, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| | 78/1000 [00:00<00:08, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| | 79/1000 [00:00<00:08, 102.62query/s, failed=0, valid
#   certcf_backward:   8%| |
#   certcf_backward:  63%|▋| 63/100 [00:34<00:21,  1.74query/s, failed=0, valid=6
#   certcf_backward:  64%|▋| 64/100 [00:34<00:20,  1.74query/s, failed=0, valid=6
#   certcf_backward:  65%|▋| 65/100 [00:36<00:22,  1.58query/s, failed=0, valid=6
#   certcf_backward:  65%|▋| 65/100 [00:36<00:22,  1.58query/s, failed=0, valid=6
#   certcf_backward:  66%|▋| 66/100 [00:36<00:21,  1.58query/s, failed=0, valid=6
#   certcf_backward:  67%|▋| 67/100 [00:36<00:14,  2.34query/s, failed=0, valid=6
#   certcf_backward:  67%|▋| 67/100 [00:36<00:14,  2.34query/s, failed=0, valid=6
#   certcf_backward:  68%|▋| 68/100 [00:36<00:13,  2.34query/s, failed=0, valid=6
#   certcf_backward:  69%|▋| 69/100 [00:37<00:12,  2.43query/s, failed=0, valid=6
#   certcf_backward:  69%|▋| 69/100 [00:37<00:12,  2.43query/s, failed=0, valid=6
#   certcf_backward:  70%|▋| 70/100 [00:37<00:12,  2.43query/s, failed=0, valid=7
#   certcf_backward:  71%|▋| 71/100 [00:37<00:11,  2.43query/s, failed=0, valid=7
#   certcf_backward:  72%|▋| 72/100 [00:37<00:09,  2.86query/s, failed=0, valid=7
#   certcf_backward:  72%|▋| 72/100 [00:37<00:09,  2.86query/s, failed=0, valid=7
#   certcf_backward:  73%|▋| 73/100 [00:38<00:09,  2.86query/s, failed=0, valid=7
#   certcf_backward:  74%|▋| 74/100 [00:38<00:09,  2.86query/s, failed=0, valid=7
#   certcf_backward:  74%|▋| 74/100 [00:38<00:09,  2.86query/s, failed=0, valid=7
#   certcf_backward:  75%|▊| 75/100 [00:38<00:08,  2.86query/s, failed=0, valid=7
#   certcf_backward:  76%|▊| 76/100 [00:39<00:07,  3.17query/s, failed=0, valid=7
#   certcf_backward:  76%|▊| 76/100 [00:39<00:07,  3.17query/s, failed=0, valid=7
#   certcf_backward:  77%|▊| 77/100 [00:39<00:08,  2.65query/s, failed=0, valid=7
#   certcf_backward:  77%|▊| 77/100 [00:39<00:08,  2.65query/s, failed=0, valid=7
#   certcf_backward:  78%|▊| 78/100 [00:39<00:08,  2.65query/s, failed=0, valid=7
#   certcf_backward:  79%|▊| 79/100 [00:39<00:07,  2.65query/s, failed=0, valid=7
#   certcf_backward:  80%|▊| 80/100 [00:39<00:04,  4.23query/s, failed=0, valid=7
#   certcf_backward:  80%|▊| 80/100 [00:39<00:04,  4.23query/s, failed=0, valid=8
#   certcf_backward:  81%|▊| 81/100 [00:41<00:08,  2.34query/s, failed=0, valid=8
#   certcf_backward:  81%|▊| 81/100 [00:41<00:08,  2.34query/s, failed=0, valid=8
#   certcf_backward:  82%|▊| 82/100 [00:42<00:08,  2.08query/s, failed=0, valid=8
#   certcf_backward:  82%|▊| 82/100 [00:42<00:08,  2.08query/s, failed=0, valid=8
#   certcf_backward:  83%|▊| 83/100 [00:42<00:08,  1.90query/s, failed=0, valid=8
#   certcf_backward:  83%|▊| 83/100 [00:42<00:08,  1.90query/s, failed=0, valid=8
#   certcf_backward:  84%|▊| 84/100 [00:43<00:08,  1.81query/s, failed=0, valid=8
#   certcf_backward:  84%|▊| 84/100 [00:43<00:08,  1.81query/s, failed=0, valid=8
#   certcf_backward:  85%|▊| 85/100 [00:43<00:08,  1.81query/s, failed=0, valid=8
#   certcf_backward:  86%|▊| 86/100 [00:44<00:06,  2.00query/s, failed=0, valid=8
#   certcf_backward:  86%|▊| 86/100 [00:44<00:06,  2.00query/s, failed=0, valid=8
#   certcf_backward:  87%|▊| 87/100 [00:44<00:05,  2.28query/s, failed=0, valid=8
#   certcf_backward:  87%|▊| 87/100 [00:44<00:05,  2.28query/s, failed=0, valid=8
#   certcf_backward:  88%|▉| 88/100 [00:45<00:06,  1.98query/s, failed=0, valid=8
#   certcf_backward:  88%|▉| 88/100 [00:45<00:06,  1.98query/s, failed=0, valid=8
#   certcf_backward:  89%|▉| 89/100 [00:45<00:05,  1.85query/s, failed=0, valid=8
#   certcf_backward:  89%|▉| 89/100 [00:45<00:05,  1.85query/s, failed=0, valid=8
#   certcf_backward:  90%|▉| 90/100 [00:46<00:04,  2.22query/s, failed=0, valid=8
#   certcf_backward:  90%|▉| 90/100 [00:46<00:04,  2.22query/s, failed=0, valid=9
#   certcf_backward:  91%|▉| 91/100 [00:46<00:03,  2.50query/s, failed=0, valid=9
#   certcf_backward:  91%|▉| 91/100 [00:46<00:03,  2.50query/s, failed=0, valid=9
#   certcf_backward:  92%|▉| 92/100 [00:46<00:03,  2.12query/s, failed=0, valid=9
#   certcf_backward:  92%|▉| 92/100 [00:46<00:03,  2.12query/s, failed=0, valid=9
#   certcf_backward:  93%|▉| 93/100 [00:47<00:03,  1.89query/s, failed=0, valid=9
#   certcf_backward:  93%|▉| 93/100 [00:47<00:03,  1.89query/s, failed=0, valid=9
#   certcf_backward:  94%|▉| 94/100 [00:48<00:03,  1.63query/s, failed=0, valid=9
#   certcf_backward:  94%|▉| 94/100 [00:48<00:03,  1.63query/s, failed=0, valid=9
#   certcf_backward:  95%|▉| 95/100 [00:48<00:03,  1.63query/s, failed=0, valid=9
#   certcf_backward:  96%|▉| 96/100 [00:49<00:02,  1.82query/s, failed=0, valid=9
#   certcf_backward:  96%|▉| 96/100 [00:49<00:02,  1.82query/s, failed=0, valid=9
#   certcf_backward:  97%|▉| 97/100 [00:50<00:01,  1.54query/s, failed=0, valid=9
#   certcf_backward:  97%|▉| 97/100 [00:50<00:01,  1.54query/s, failed=0, valid=9
#   certcf_backward:  98%|▉| 98/100 [00:50<00:01,  1.54query/s, failed=0, valid=9
#   certcf_backward:  99%|▉| 99/100 [00:50<00:00,  2.46query/s, failed=0, valid=9
#   certcf_backward:  99%|▉| 99/100 [00:50<00:00,  2.46query/s, failed=0, valid=9
#   certcf_backward: 100%|█| 100/100 [00:50<00:00,  2.64query/s, failed=0, valid=
#   certcf_backward: 100%|█| 100/100 [00:50<00:00,  1.97query/s, failed=0, valid=
#   nn_probe:  93%|█████▌| 52/56 [00:00<00:00, 308.08query/s, failed=0, valid=52]
# [INFO] Saved benchmark parquet to /home/gabrielepintus/Documents/github/PreimageCounterfactualSampling/results/certcf_probe_adult_german_credit.parquet
#
# BENCHMARK SUMMARY
# method           validity%      l2_mean    l1_mean  sparsity%      build_s    query_s    n_failed
# ---------------  -----------  ---------  ---------  -----------  ---------  ---------  ----------
# nn_probe         100.0%           3.307      9.809  16.9%             0         0               0
# certcf_backward  100.0%           3.33       9.875  17.0%            12.54      0.506           0
# [INFO] german_credit: 200 rows, 100.0% valid
#
# ============================================================
# [DATASET 7/7]  wisconsin_breast_cancer
# ============================================================
# [INFO] Loading TabularClassifier from checkpoint: checkpoints/wisconsin_breast_cancer_classifier/best.ckpt
# [INFO] model device normalized: 'auto' -> 'cuda'
# [INFO] Train accuracy: 0.991
# [INFO] 56 benchmark tasks selected from 56 test samples.
# [INFO] Preprocessing: identity (30 -> 30 dims).
# [INFO] 2 method runs after grid expansion.
#
# [METHOD] nn_probe (impl: nearest_neighbor)
#   [build] 0.00s
#
# [METHOD] certcf_backward (impl: certcf)
# [INFO] certcf device normalized: 'auto' -> 'cuda'
# Building certified atlas (eps in [1.078, 11.13] (NearestOppositeClassClearanceStrategy), L1 norm)...
#   Computing LiRPA bounds...
#   nn_probe: 100%|██████| 56/56 [00:00<00:00, 308.08query/s, failed=0, valid=56]
# Computing bounds:   0%|                                  | 0/2 [00:00<?, ?it/s]/home/gabrielepintus/.conda/envs/py13/lib/python3.13/site-packages/auto_LiRPA/perturbations.py:199: RuntimeWarning: divide by zero encountered in scalar divide
#   self.dual_norm = 1 if (norm == np.inf) else (np.float64(1.0) / (1 - 1.0 / self.norm))
# /home/gabrielepintus/.conda/envs/py13/lib/python3.13/site-packages/auto_LiRPA/operators/linear.py:650: RuntimeWarning: divide by zero encountered in scalar divide
#   dual_norm = np.float64(1.0) / (1 - 1.0 / norm)
#
# Computing bounds:  50%|█████████████             | 1/2 [00:04<00:04,  4.33s/it]
# Computing bounds: 100%|██████████████████████████| 2/2 [00:07<00:00,  3.58s/it]
#
#   nn_probe: 100%|███████| 56/56 [00:07<00:00,  7.64query/s, failed=0, valid=56]
#
#   certcf_backward:   2%|  | 1/56 [00:00<00:01, 30.75query/s, failed=0, valid=1]
#   certcf_backward:   4%|  | 2/56 [00:00<00:01, 40.87query/s, failed=0, valid=2]
#   certcf_backward:   5%|  | 3/56 [00:00<00:01, 46.07query/s, failed=0, valid=3]
#   certcf_backward:   7%|▏ | 4/56 [00:00<00:01, 48.50query/s, failed=0, valid=4]
#   certcf_backward:   9%|▏ | 5/56 [00:00<00:01, 47.92query/s, failed=0, valid=4]
#   certcf_backward:   9%|▏ | 5/56 [00:00<00:01, 47.92query/s, failed=0, valid=5]
#   certcf_backward:  11%|▏ | 6/56 [00:00<00:01, 47.92query/s, failed=0, valid=6]
#   certcf_backward:  12%|▎ | 7/56 [00:00<00:01, 47.92query/s, failed=0, valid=7]
#   certcf_backward:  14%|▎ | 8/56 [00:00<00:01, 47.92query/s, failed=0, valid=8]
#   certcf_backward:  16%|▎ | 9/56 [00:00<00:00, 47.92query/s, failed=0, valid=9]
#   Building BVH spatial indices...
#     Class 0: 283 polytopes, tree depth 10
#     Class 1: 174 polytopes, tree depth 9
# Done! Total: 457 polytopes across 2 classes
#   [build] 7.17s
#   certcf_backward:  18%|▏| 10/56 [00:00<00:00, 47.92query/s, failed=0, valid=10
#   certcf_backward:  20%|▏| 11/56 [00:00<00:00, 49.87query/s, failed=0, valid=10
#   certcf_backward:  20%|▏| 11/56 [00:00<00:00, 49.87query/s, failed=0, valid=11
#   certcf_backward:  21%|▏| 12/56 [00:00<00:00, 49.87query/s, failed=0, valid=12
#   certcf_backward:  23%|▏| 13/56 [00:00<00:00, 49.87query/s, failed=0, valid=13
#   certcf_backward:  25%|▎| 14/56 [00:00<00:00, 49.87query/s, failed=0, valid=14
#   certcf_backward:  27%|▎| 15/56 [00:00<00:00, 49.87query/s, failed=0, valid=15
#   certcf_backward:  29%|▎| 16/56 [00:00<00:00, 49.87query/s, failed=0, valid=16
#   certcf_backward:  30%|▎| 17/56 [00:00<00:00, 52.44query/s, failed=0, valid=16
#   certcf_backward:  30%|▎| 17/56 [00:00<00:00, 52.44query/s, failed=0, valid=17
#   certcf_backward:  32%|▎| 18/56 [00:00<00:00, 52.44query/s, failed=0, valid=18
#   certcf_backward:  34%|▎| 19/56 [00:00<00:00, 52.44query/s, failed=0, valid=19
#   certcf_backward:  36%|▎| 20/56 [00:00<00:00, 52.44query/s, failed=0, valid=20
#   certcf_backward:  38%|▍| 21/56 [00:00<00:00, 52.44query/s, failed=0, valid=21
#   certcf_backward:  39%|▍| 22/56 [00:00<00:00, 52.44query/s, failed=0, valid=22
#   certcf_backward:  41%|▍| 23/56 [00:00<00:00, 49.74query/s, failed=0, valid=22
#   certcf_backward:  41%|▍| 23/56 [00:00<00:00, 49.74query/s, failed=0, valid=23
#   certcf_backward:  43%|▍| 24/56 [00:00<00:00, 49.74query/s, failed=0, valid=24
#   certcf_backward:  45%|▍| 25/56 [00:00<00:00, 49.74query/s, failed=0, valid=25
#   certcf_backward:  46%|▍| 26/56 [00:00<00:00, 49.74query/s, failed=0, valid=26
#   certcf_backward:  48%|▍| 27/56 [00:00<00:00, 49.74query/s, failed=0, valid=27
#   certcf_backward:  50%|▌| 28/56 [00:00<00:00, 49.74query/s, failed=0, valid=28
#   certcf_backward:  52%|▌| 29/56 [00:00<00:00, 50.96query/s, failed=0, valid=28
#   certcf_backward:  52%|▌| 29/56 [00:00<00:00, 50.96query/s, failed=0, valid=29
#   certcf_backward:  54%|▌| 30/56 [00:00<00:00, 50.96query/s, failed=0, valid=30
#   certcf_backward:  55%|▌| 31/56 [00:00<00:00, 50.96query/s, failed=0, valid=31
#   certcf_backward:  57%|▌| 32/56 [00:00<00:00, 50.96query/s, failed=0, valid=32
#   certcf_backward:  59%|▌| 33/56 [00:00<00:00, 50.96query/s, failed=0, valid=33
#   certcf_backward:  61%|▌| 34/56 [00:00<00:00, 50.96query/s, failed=0, valid=34
#   certcf_backward:  62%|▋| 35/56 [00:00<00:00, 52.75query/s, failed=0, valid=34
#   certcf_backward:  62%|▋| 35/56 [00:00<00:00, 52.75query/s, failed=0, valid=35
#   certcf_backward:  64%|▋| 36/56 [00:00<00:00, 52.75query/s, failed=0, valid=36
#   certcf_backward:  66%|▋| 37/56 [00:00<00:00, 52.75query/s, failed=0, valid=37
#   certcf_backward:  68%|▋| 38/56 [00:00<00:00, 52.75query/s, failed=0, valid=38
#   certcf_backward:  70%|▋| 39/56 [00:00<00:00, 52.75query/s, failed=0, valid=39
#   certcf_backward:  71%|▋| 40/56 [00:00<00:00, 52.75query/s, failed=0, valid=40
#   certcf_backward:  73%|▋| 41/56 [00:00<00:00, 53.06query/s, failed=0, valid=40
#   certcf_backward:  73%|▋| 41/56 [00:00<00:00, 53.06query/s, failed=0, valid=41
#   certcf_backward:  75%|▊| 42/56 [00:00<00:00, 53.06query/s, failed=0, valid=42
#   certcf_backward:  77%|▊| 43/56 [00:00<00:00, 53.06query/s, failed=0, valid=43
#   certcf_backward:  79%|▊| 44/56 [00:00<00:00, 53.06query/s, failed=0, valid=44
#   certcf_backward:  80%|▊| 45/56 [00:00<00:00, 53.06query/s, failed=0, valid=45
#   certcf_backward:  82%|▊| 46/56 [00:00<00:00, 53.06query/s, failed=0, valid=46
#   certcf_backward:  84%|▊| 47/56 [00:00<00:00, 51.59query/s, failed=0, valid=46
#   certcf_backward:  84%|▊| 47/56 [00:00<00:00, 51.59query/s, failed=0, valid=47
#   certcf_backward:  86%|▊| 48/56 [00:00<00:00, 51.59query/s, failed=0, valid=48
#   certcf_backward:  88%|▉| 49/56 [00:00<00:00, 51.59query/s, failed=0, valid=49
#   certcf_backward:  89%|▉| 50/56 [00:00<00:00, 51.59query/s, failed=0, valid=50
#   certcf_backward:  91%|▉| 51/56 [00:01<00:00, 51.59query/s, failed=0, valid=51
#   certcf_backward:  93%|▉| 52/56 [00:01<00:00, 51.59query/s, failed=0, valid=52
#   certcf_backward:  95%|▉| 53/56 [00:01<00:00, 49.81query/s, failed=0, valid=52
#   certcf_backward:  95%|▉| 53/56 [00:01<00:00, 49.81query/s, failed=0, valid=53
#   certcf_backward:  96%|▉| 54/56 [00:01<00:00, 49.81query/s, failed=0, valid=54
#   certcf_backward:  98%|▉| 55/56 [00:01<00:00, 49.81query/s, failed=0, valid=55
#   certcf_backward: 100%|█| 56/56 [00:01<00:00, 49.10query/s, failed=0, valid=56
# [INFO] Saved benchmark parquet to /home/gabrielepintus/Documents/github/PreimageCounterfactualSampling/results/certcf_probe_adult_wisconsin_breast_cancer.parquet
#
# BENCHMARK SUMMARY
# method           validity%      l2_mean    l1_mean  sparsity%      build_s    query_s    n_failed
# ---------------  -----------  ---------  ---------  -----------  ---------  ---------  ----------
# nn_probe         100.0%           4.203     18.239  100.0%            0         0               0
# certcf_backward  100.0%           3.988     16.798  99.5%             7.17      0.017           0
# [INFO] wisconsin_breast_cancer: 112 rows, 100.0% valid
#
# [INFO] Combined results (9546 rows) saved to /home/gabrielepintus/Documents/github/PreimageCounterfactualSampling/results/certcf_probe_adult.parquet
#
# [SUMMARY PER DATASET]
#                                          valid  total  valid%
# dataset                 run_name
# adult                   certcf_backward   1000   1000   100.0
#                         nn_probe          1000   1000   100.0
# compas                  certcf_backward    617    617   100.0
#                         nn_probe           617    617   100.0
# german_credit           certcf_backward    100    100   100.0
#                         nn_probe           100    100   100.0
# give_me_some_credit     certcf_backward   1000   1000   100.0
#                         nn_probe          1000   1000   100.0
# heloc                   certcf_backward   1000   1000   100.0
#                         nn_probe          1000   1000   100.0
# lending_club            certcf_backward   1000   1000   100.0
#                         nn_probe          1000   1000   100.0
# wisconsin_breast_cancer certcf_backward     56     56   100.0
#                         nn_probe            56     56   100.0
# (9546, 291)

# %%
def _cf_columns(frame):
    return sorted([c for c in frame.columns if c.startswith("x_cf_")], key=lambda c: int(c.rsplit("_", 1)[1]))


def _is_training_point_matrix(x_cf, x_train, atol=1e-6, chunk_size=4096):
    hits = np.zeros(len(x_cf), dtype=bool)
    finite = np.isfinite(x_cf).all(axis=1)
    for start in range(0, len(x_train), chunk_size):
        train_chunk = x_train[start:start + chunk_size]
        hits[finite] |= np.isclose(x_cf[finite, None, :], train_chunk[None, :, :], atol=atol, rtol=0.0).all(axis=2).any(axis=1)
    return hits


loader = DATASET_LOADERS[DATASET](data_dir=str(ROOT / "data"), seed=42)
loader.load()
x_train, _ = loader.get_train()
cf_cols = _cf_columns(df)
df = df.copy()
df["cf_is_training_point"] = np.nan
if cf_cols:
    successful = df["success"].astype(bool).to_numpy()
    x_cf = df.loc[successful, cf_cols].to_numpy(dtype=np.float32)
    df.loc[successful, "cf_is_training_point"] = _is_training_point_matrix(x_cf, x_train).astype(float)

summary = df.groupby(["dataset", "run_name"]).agg(
    n=("success", "size"),
    validity=("success", "mean"),
    returned_cfs=("cf_is_training_point", "count"),
    train_point_probability=("cf_is_training_point", "mean"),
    train_point_hits=("cf_is_training_point", "sum"),
    l1_mean=("l1_distance", "mean"),
    l1_median=("l1_distance", "median"),
    query_s=("runtime_s", "mean"),
)
for col in ["meta__nearest_anchor_returned", "meta__n_qp_solved", "meta__target_reached"]:
    if col in df.columns:
        summary[col.replace("meta__", "")] = df.groupby(["dataset", "run_name"])[col].mean()
display(summary.round(4))
# Out:
#                                             n  validity  returned_cfs  \
# dataset                 run_name
# adult                   certcf_backward  1000       1.0          1000
#                         nn_probe         1000       1.0          1000
# compas                  certcf_backward   617       1.0           617
#                         nn_probe          617       1.0           617
# german_credit           certcf_backward   100       1.0           100
#                         nn_probe          100       1.0           100
# give_me_some_credit     certcf_backward  1000       1.0          1000
#                         nn_probe         1000       1.0          1000
# heloc                   certcf_backward  1000       1.0          1000
#                         nn_probe         1000       1.0          1000
# lending_club            certcf_backward  1000       1.0          1000
#                         nn_probe         1000       1.0          1000
# wisconsin_breast_cancer certcf_backward    56       1.0            56
#                         nn_probe           56       1.0            56
#
#                                          train_point_probability  \
# dataset                 run_name
# adult                   certcf_backward                     0.24
#                         nn_probe                            1.00
# compas                  certcf_backward                     0.00
#                         nn_probe                            0.00
# german_credit           certcf_backward                     0.00
#                         nn_probe                            0.00
# give_me_some_credit     certcf_backward                     0.00
#                         nn_probe                            0.00
# heloc                   certcf_backward                     0.00
#                         nn_probe                            0.00
# lending_club            certcf_backward                     0.00
#                         nn_probe                            0.00
# wisconsin_breast_cancer certcf_backward                     0.00
#                         nn_probe                            0.00
#
#                                          train_point_hits  l1_mean  l1_median  \
# dataset                 run_name
# adult                   certcf_backward             240.0   6.8057     6.7113
#                         nn_probe                   1000.0   5.9199     5.8235
# compas                  certcf_backward               0.0   1.2099     0.9161
#                         nn_probe                      0.0   1.2719     0.9735
# german_credit           certcf_backward               0.0   9.8753     9.5858
#                         nn_probe                      0.0   9.8095     9.7356
# give_me_some_credit     certcf_backward               0.0   1.0165     0.7181
#                         nn_probe                      0.0   1.0824     0.7839
# heloc                   certcf_backward               0.0  10.5148     8.0849
#                         nn_probe                      0.0  10.5611     8.1680
# lending_club            certcf_backward               0.0   4.6108     4.5030
#                         nn_probe                      0.0   4.7541     4.6338
# wisconsin_breast_cancer certcf_backward               0.0  16.7981    15.8922
#                         nn_probe                      0.0  18.2385    17.0198
#
#                                          query_s  nearest_anchor_returned  \
# dataset                 run_name
# adult                   certcf_backward   0.1237                    0.239
#                         nn_probe          0.0001                      NaN
# compas                  certcf_backward   0.0359                    0.000
#                         nn_probe          0.0001                      NaN
# german_credit           certcf_backward   0.5059                    0.030
#                         nn_probe          0.0001                      NaN
# give_me_some_credit     certcf_backward   0.0088                    0.000
#                         nn_probe          0.0001                      NaN
# heloc                   certcf_backward   0.0161                    0.018
#                         nn_probe          0.0001                      NaN
# lending_club            certcf_backward   0.0530                    0.001
#                         nn_probe          0.0001                      NaN
# wisconsin_breast_cancer certcf_backward   0.0173                    0.000
#                         nn_probe          0.0001                      NaN
#
#                                          n_qp_solved  target_reached
# dataset                 run_name
# adult                   certcf_backward       4.5640             1.0
#                         nn_probe                 NaN             1.0
# compas                  certcf_backward       1.9206             1.0
#                         nn_probe                 NaN             1.0
# german_credit           certcf_backward       5.0000             1.0
#                         nn_probe                 NaN             1.0
# give_me_some_credit     certcf_backward       2.9420             1.0
#                         nn_probe                 NaN             1.0
# heloc                   certcf_backward       4.9960             1.0
#                         nn_probe                 NaN             1.0
# lending_club            certcf_backward       4.6570             1.0
#                         nn_probe                 NaN             1.0
# wisconsin_breast_cancer certcf_backward       5.0000             1.0
#                         nn_probe                 NaN             1.0
