# %%
# first prepare a task
from robustx.datasets.ExampleDatasets import get_example_dataset
from robustx.lib.models.pytorch_models.SimpleNNModel import SimpleNNModel
from robustx.lib.tasks.ClassificationTask import ClassificationTask
from robustx.lib.DefaultBenchmark import default_benchmark

# %%
data = get_example_dataset("ionosphere")
data.default_preprocess()
model = SimpleNNModel(34, [8], 1)
model.train(data.X, data.y)
task = ClassificationTask(model, data)

# %%
methods = ["KDTreeNNCE", "MCE", "MCER", "RNCE", "STCE", "PROPLACE"]
evaluations = ["Validity", "Distance", "Delta-robustness"]
default_benchmark(task, methods, evaluations, neg_value=0, column_name="target", delta=0.005)
# Out:
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 methods = ["KDTreeNNCE", "MCE", "MCER", "RNCE", "STCE", "PROPLACE"]
#       2 evaluations = ["Validity", "Distance", "Delta-robustness"]
# ----> 3 default_benchmark(task, methods, evaluations, neg_value=0, column_name="target", delta=0.005)
#
# File ~/Documents/github/PreimageCounterfactualSampling/RobustX/robustx/lib/DefaultBenchmark.py:70, in default_benchmark(ct, methods, evaluations, subset, **params)
#      68 for eval_name in evaluations:
#      69     ce_evaluator = EVALUATIONS[eval_name](ct)
# ---> 70     eval_results.append(ce_evaluator.evaluate(ces, **params))
#      72 # Add to results
#      73 results.append(eval_results)
#
# File ~/Documents/github/PreimageCounterfactualSampling/RobustX/robustx/evaluations/RobustnessProportionEvaluator.py:59, in RobustnessProportionEvaluator.evaluate(self, counterfactuals, delta, bias_delta, M, epsilon, valid_val, column_name, robustness_evaluator, **kwargs)
#      56 # Get only the feature variables from the CEs
#      57 instances = counterfactuals.drop(columns=[column_name, "loss"], errors='ignore')
# ---> 59 robustness_evaluator = robustness_evaluator(self.task)
#      61 for _, instance in instances.iterrows():
#      62
#      63     # Increment robust if CE is robust under given parameters
#      64     if instance is not None and robustness_evaluator.evaluate(instance, desired_output=valid_val,
#      65                                                               delta=delta, bias_delta=bias_delta,
#      66                                                               M=M, epsilon=epsilon):
#
# File ~/Documents/github/PreimageCounterfactualSampling/RobustX/robustx/robustness_evaluations/DeltaRobustnessEvaluator.py:28, in DeltaRobustnessEvaluator.__init__(self, ct)
#      22 """
#      23 Initializes the DeltaRobustnessEvaluator with a given task.
#      24
#      25 @param ct: The task to solve, provided as a Task instance.
#      26 """
#      27 super().__init__(ct)
# ---> 28 self.opt = OptSolver(ct)
#
# File ~/Documents/github/PreimageCounterfactualSampling/RobustX/robustx/lib/OptSolver.py:40, in OptSolver.__init__(self, ct)
#      34 """
#      35 Initializes the OptSolver with a given Task.
#      36
#      37 @param ct: Task, The task to be optimized.
#      38 """
#      39 self.task = ct
# ---> 40 self.gurobiModel = Model()
#      41 self.inputNodes = None
#      42 self.outputNode = None
#
# File src/gurobipy/model.pxi:80, in gurobipy.Model.__init__()
#
# File src/gurobipy/gurobi.pxi:60, in gurobipy.gurobi._getdefaultenv()
#
# File src/gurobipy/env.pxi:70, in gurobipy.Env.__init__()
#
# GurobiError: License expired 2025-11-24
